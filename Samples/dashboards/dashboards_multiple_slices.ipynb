# %%
import os,sys
import OpenVisus  as  ov
from  OpenVisus.dashboards  import  Slices
from bokeh.io import output_notebook, show
from bokeh.application import Application
from bokeh.application.handlers import FunctionHandler
# os.environ["BOKEH_ALLOW_WS_ORIGIN"]="localhost:8889" 
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6976">Loading BokehJS ...</span>
#     </div>

# %%
db=ov.LoadDataset(f"https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?profile=wasabi&cached=idx&blob_extension=.bin.zz")
slices=Slices()
slices.setDataset(db,layout=3)
# Out:
# Slices:: setPalette Greys256 (0, 1.0)
# Slice:: setPalette 2 Greys256 (0, 1.0)
# Slice:: setPalette 0 Greys256 (0, 1.0)
# Slice:: setPalette 1 Greys256 (0, 1.0)
# Slice:: setPalette 2 Greys256 (0, 1.0)

# %%
def modify_doc(doc):
    slices.setPalette("Greys256", palette_range=(0.0, 65535.0))
    doc.add_root(slices.layout)    
    doc.theme = 'caliber'
    slices.widgets.nviews.value='4'
    doc.add_periodic_callback(slices.getCentralLayout, 100)
# Out:
# ame /Users/aashishpanta/.aws/config
# 222342833 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222342833 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222342933 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222342934 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222342934 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222342934 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222342934 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222343032 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222343033 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222343033 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222343033 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222343033 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222343134 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222343134 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222343134 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222343134 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222343134 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222343237 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222343237 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222343237 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222343237 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222343237 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222343340 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222343340 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222343340 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222343340 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222343340 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222343443 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222343443 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222343443 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222343443 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222343443 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222343546 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222343547 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222343547 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222343547 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222343547 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222343649 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222343649 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222343649 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222343649 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222343649 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222343747 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222343747 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222343747 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222343747 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222343748 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222343848 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222343848 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222343849 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222343849 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222343849 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222343854 Dataset:231 9092:0x2028432c0 Automatically enabling caching for https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi
#  <access type="multiplex">
# 	<access type="IdxDiskAccess" chmod="rw" compression="zip" cache_dir="/Users/aashishpanta/visus/cache" />
# 	<access type="CloudStorageAccess" chmod="r" compression="zip" />
# </access>
# 222343854 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222343854 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344104 NetService:785 9092:0x38619b000 GET connection 0 wait 10 running 239 download 274  -  1 kb/sec) status STATUS_OK url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=679JYS0BFPLDDA3C975U%2F20221215%2Fus-west-1%2Fs3%2Faws4_request&X-Amz-Date=20221215T052343Z&X-Amz-Expires=3600&X-Amz-Signature=092d9c3bed76fd074cf1524b369bb2c32a653549a965673f43863edc752a1af0&X-Amz-SignedHeaders=host
# 222344116 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344116 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344116 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344116 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344116 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222344125 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344125 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344125 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344126 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344126 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222344134 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344135 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344135 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344135 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344135 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222344160 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344160 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q

# %%
show(modify_doc)
# Out:
# <script id="7850">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:54042/autoload.js?bokeh-autoload-element=7850&bokeh-absolute-url=http://localhost:54042&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
# Slices:: setPalette Greys256 (0.0, 65535.0)
# Slice:: setPalette 2 Greys256 (0.0, 65535.0)
# Slice:: setPalette 0 Greys256 (0.0, 65535.0)
# Slice:: setPalette 1 Greys256 (0.0, 65535.0)
# Slice:: setPalette 2 Greys256 (0.0, 65535.0)
# Slices:: setPalette Greys256 (0, 65535.0)
# Slice:: setPalette 2 Greys256 (0, 65535.0)
# Slice:: setPalette 2 Greys256 (0, 65535.0)
# Slice:: setPalette 0 Greys256 (0, 65535.0)
# Slice:: setPalette 1 Greys256 (0, 65535.0)
# Slice:: setPalette 2 Greys256 (0, 65535.0)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Select(id='7254', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Select(id='7247', ...)
# 3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344160 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344160 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344160 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222344261 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344261 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344261 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344261 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344261 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222344363 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344364 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344364 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344364 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344364 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222344471 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344472 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344472 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344472 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344472 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222344574 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344575 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344575 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344575 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344575 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222344680 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344680 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344680 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344680 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344681 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222344781 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344781 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344781 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344781 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344781 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222344881 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222344882 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222344882 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222344882 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222344882 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345075 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345076 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345076 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345076 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345076 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345086 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345086 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345086 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345086 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345086 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345096 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345096 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345096 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345096 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345096 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345105 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345105 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345105 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345105 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345105 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345268 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345269 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345269 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345269 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345269 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345373 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345373 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345374 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345374 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345374 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345471 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345472 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345472 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345472 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345472 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345584 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345584 IdxDiskAccess:1050 9092:0xPyQuery::Got new job logic_box ([0, 1280, -793.6729222520107], [2560, 1281, 2953.6729222520107]) num_refinements 4 max_pixels 203658
# read ([0, 1280, -793.6729222520107], [2560, 1281, 2953.6729222520107])
# PyQuery::Got new job logic_box ([1280, 0, -793.6729222520107], [1281, 2560, 2953.6729222520107]) num_refinements 4 max_pixels 203658
# read ([1280, 0, -793.6729222520107], [1281, 2560, 2953.6729222520107])
#     Got data 0/4 ([0, 1280, 0], [2560, 1281, 2176]) data=(34, 80)/float64 #pixels=(34, 80)/2,720 #max=203,658/203,658 m=0.0 M=60733.1054768856    Got data 0/4 ([1280, 0, 0], [1281, 2560, 2176]) data=(34, 80)/float64 #pixels=(34, 80)/2,720 #max=203,658/203,658 m=0.0 M=65535.0
#
# PyQuery::Got new job logic_box ([0, -593.6729222520107, 1080], [2560, 3153.6729222520107, 1081]) num_refinements 4 max_pixels 203658
# read ([0, -593.6729222520107, 1080], [2560, 3153.6729222520107, 1081])
#     Got data 0/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(40, 80)/float64 #pixels=(40, 80)/3,200 #max=203,658/203,658 m=0.0 M=63011.57247251269
# PyQuery::Got new job logic_box ([0, -593.6729222520107, 1080], [2560, 3153.6729222520107, 1081]) num_refinements 4 max_pixels 203658
# read ([0, -593.6729222520107, 1080], [2560, 3153.6729222520107, 1081])
#     Got data 1/4 ([0, 1280, 0], [2560, 1281, 2176]) data=(68, 160)/float64 #pixels=(68, 160)/10,880 #max=203,658/203,658 m=0.0 M=63213.309448723536
#     Got data 1/4 ([1280, 0, 0], [1281, 2560, 2176]) data=(68, 160)/float64 #pixels=(68, 160)/10,880 #max=203,658/203,658 m=0.0 M=65535.0    Got data 1/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(80, 160)/float64 #pixels=(80, 160)/12,800 #max=203,658/203,658 m=0.0 M=65535.0
#
#     Got data 0/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(40, 80)/float64 #pixels=(40, 80)/3,200 #max=203,658/203,658 m=0.0 M=63011.57247251269
#     Got data 1/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(80, 160)/float64 #pixels=(80, 160)/12,800 #max=203,658/203,658 m=0.0 M=65535.0
#     Got data 2/4 ([0, 1280, 0], [2560, 1281, 2176]) data=(136, 320)/float64 #pixels=(136, 320)/43,520 #max=203,658/203,658 m=0.0 M=65535.0
#     Got data 2/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(160, 320)/float64 #pixels=(160, 320)/51,200 #max=203,658/203,658 m=0.0 M=65535.0    Got data 2/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(160, 320)/float64 #pixels=(160, 320)/51,200 #max=203,658/203,658 m=0.0 M=65535.0
#
#     Got data 2/4 ([1280, 0, 0], [1281, 2560, 2176]) data=(136, 320)/float64 #pixels=(136, 320)/43,520 #max=203,658/203,658 m=0.0 M=65535.0
# PyQuery::done_job
#     Got data 3/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(320, 640)/float64 #pixels=(320, 640)/204,800 #max=203,658/203,658 m=0.0 M=65535.0PyQuery::Got new job logic_box ([0, 1280, -798.7096774193549], [2560, 1281, 2958.709677419355])    Got data 3/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(320, 640)/float64 #pixels=(320, 640)/204,800 #max=203,658/203,658 m=0.0 M=65535.0
# PyQuery::done_job
#
#  num_refinements 4 max_pixels 203112
# read ([0, 1280, -798.7096774193549], [2560, 1281, 2958.709677419355])
# PyQuery::done_job
#     Got data 3/4 ([1280, 0, 0], [1281, 2560, 2176]) data=(272, 640)/float64 #pixels=(272, 640)/174,080 #max=203,658/203,658 m=0.0 M=65535.0
# PyQuery::done_job
#     Got data 0/4 ([0, 1280, 0], [2560, 1281, 2176]) data=(34, 80)/float64 #pixels=(34, 80)/2,720 #max=203,112/203,112 m=0.0 M=60733.1054768856
#     Got data 1/4 ([0, 1280, 0], [2560, 1281, 2176]) data=(68, 160)/float64 #pixels=(68, 160)/10,880 #max=203,112/203,112 m=0.0 M=63213.309448723536
# PyQuery::Got new job logic_box ([1280, 0, -798.7096774193549], [1281, 2560, 2958.709677419355]) num_refinements 4 max_pixels 203112
# read ([1280, 0, -798.7096774193549], [1281, 2560, 2958.709677419355])
#     Got data 2/4 ([0, 1280, 0], [2560, 1281, 2176]) data=(136, 320)/float64 #pixels=(136, 320)/43,520 #max=203,112/203,112 m=0.0 M=65535.0
#     Got data 0/4 ([1280, 0, 0], [1281, 2560, 2176]) data=(34, 80)/float64 #pixels=(34, 80)/2,720 #max=203,112/203,112 m=0.0 M=65535.0
#     Got data 1/4 ([1280, 0, 0], [1281, 2560, 2176]) data=(68, 160)/float64 #pixels=(68, 160)/10,880 #max=203,112/203,112 m=0.0 M=65535.0
# PyQuery::Got new job logic_box ([0, -598.7096774193549, 1080], [2560, 3158.709677419355, 1081]) num_refinements 4 max_pixels 203112
# read ([0, -598.7096774193549, 1080], [2560, 3158.709677419355, 1081])
#     Got data 3/4 ([0, 1280, 0], [2560, 1281, 2176]) data=(272, 640)/float64 #pixels=(272, 640)/174,080 #max=203,112/203,112 m=0.0 M=65535.0    Got data 2/4 ([1280, 0, 0], [1281, 2560, 2176]) data=(136, 320)/float64 #pixels=(136, 320)/43,520 #max=203,112/203,112 m=0.0 M=65535.0
#
# PyQuery::done_job
#     Got data 0/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(40, 80)/float64 #pixels=(40, 80)/3,200 #max=203,112/203,112 m=0.0 M=63011.57247251269
#     Got data 1/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(80, 160)/float64 #pixels=(80, 160)/12,800 #max=203,112/203,112 m=0.0 M=65535.0
#     Got data 2/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(160, 320)/float64 #pixels=(160, 320)/51,200 #max=203,112/203,112 m=0.0 M=65535.0
#     Got data 3/4 ([1280, 0, 0], [1281, 2560, 2176]) data=(272, 640)/float64 #pixels=(272, 640)/174,080 #max=203,112/203,112 m=0.0 M=65535.0
# PyQuery::done_job
#     Got data 3/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(320, 640)/float64 #pixels=(320, 640)/204,800 #max=203,112/203,112 m=0.0 M=65535.0
# PyQuery::done_job
# Statistics enlapsed=0.17
#    IO  r=788.20MiB r_sec=4.41GiB/sec w=0 w_sec=0.0/sec n=159 n_sec=910/sec
#    NET r=0 r_sec=0.0/sec w=0 w_sec=0.0/sec n=0 n_sec=0/sec
# PyQuery::Got new job logic_box ([0, -598.7096774193549, 1080], [2560, 3158.709677419355, 1081]) num_refinements 4 max_pixels 203112
# read ([0, -598.7096774193549, 1080], [2560, 3158.709677419355, 1081])
#     Got data 0/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(40, 80)/float64 #pixels=(40, 80)/3,200 #max=203,112/203,112 m=0.0 M=63011.57247251269
#     Got data 1/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(80, 160)/float64 #pixels=(80, 160)/12,800 #max=203,112/203,112 m=0.0 M=65535.0
#     Got data 2/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(160, 320)/float64 #pixels=(160, 320)/51,200 #max=203,112/203,112 m=0.0 M=65535.0
#     Got data 3/4 ([0, 0, 1024], [2560, 2560, 1025]) data=(320, 640)/float64 #pixels=(320, 640)/204,800 #max=203,112/203,112 m=0.0 M=65535.0
# PyQuery::done_job
# Statistics enlapsed=0.017
#    IO  r=112.03MiB r_sec=6.35GiB/sec w=0 w_sec=0.0/sec n=23 n_sec=1,334/sec
#    NET r=0 r_sec=0.0/sec w=0 w_sec=0.0/sec n=0 n_sec=0/sec
# 2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345584 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345584 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345585 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345691 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345692 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345692 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345692 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345692 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345787 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345787 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345787 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345787 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345787 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345876 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345876 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345877 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345877 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345877 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222345985 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222345985 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222345985 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222345985 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222345985 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222346085 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222346085 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222346085 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222346085 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222346085 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222346179 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222346180 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222346180 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222346180 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222346180 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222346282 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222346282 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222346282 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222346282 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222346282 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222346388 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222346389 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222346389 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222346389 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222346389 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222346497 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222346497 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222346497 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222346497 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222346498 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222346601 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222346602 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222346602 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222346602 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222346602 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222346701 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222346701 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222346701 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222346701 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222346701 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222346804 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222346804 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222346804 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222346805 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222346805 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222346910 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222346910 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222346911 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222346911 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222346911 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222347007 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222347007 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222347007 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222347008 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222347008 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222347109 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222347110 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222347110 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222347110 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222347110 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222347207 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222347207 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222347207 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222347207 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222347207 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222347313 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222347314 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222347314 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222347314 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222347314 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222347410 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222347410 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222347411 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222347411 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222347411 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222347512 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222347512 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222347512 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222347512 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222347512 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222347615 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222347616 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222347616 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222347616 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# 222347616 CloudStorageAccess:87 9092:0x2028432c0 Created CloudStorageAccess url https://s3.us-west-1.wasabisys.com/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx?blob_extension=%2Ebin%2Ezz&profile=wasabi filename_template /Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus/$(time)/$(field)/$(block:%016x:%04x).bin.zz compression zip nconnections 64
# 222347717 IdxDiskAccess:959 9092:0x2028432c0 Trying to use file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx as cache location...
# 222347717 IdxDiskAccess:1050 9092:0x2028432c0 Created IdxDiskAccess url file:///Users/aashishpanta/visus/cache/s3.us-west-1.wasabisys.com/80/Pania_2021Q3_in_situ_data/workflow/fly_scan_id_112509.h5/r/idx/1mb/visus.idx compression zip bDisableWriteLocks False
# 222347717 AmazonCloudStorage:271 9092:0x2028432c0 aws_config_filename /Users/aashishpanta/.aws/config
# 222347718 AmazonCloudStorage:286 9092:0x2028432c0 aws_credential_filename /Users/aashishpanta/.aws/credentials
# ...
#     return invoke_with_curdoc(doc, invoke)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 449, in invoke
#     return f(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 527, in getCentralLayout
#     slice=Slice()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 299, in __init__
#     self.query.startThread()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/pyquery.py", line 87, in startThread
#     self.thread.start()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/threading.py", line 892, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 93, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 227, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 450, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 449, in invoke
#     return f(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 527, in getCentralLayout
#     slice=Slice()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 299, in __init__
#     self.query.startThread()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/pyquery.py", line 87, in startThread
#     self.thread.start()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/threading.py", line 892, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
#
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 93, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 227, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 450, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 449, in invoke
#     return f(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 527, in getCentralLayout
#     slice=Slice()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 299, in __init__
#     self.query.startThread()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/pyquery.py", line 87, in startThread
#     self.thread.start()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/threading.py", line 892, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
#
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 93, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 227, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 450, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 449, in invoke
#     return f(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 527, in getCentralLayout
#     slice=Slice()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 299, in __init__
#     self.query.startThread()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/pyquery.py", line 87, in startThread
#     self.thread.start()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/threading.py", line 892, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
#
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 93, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 227, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 450, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 449, in invoke
#     return f(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 527, in getCentralLayout
#     slice=Slice()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 299, in __init__
#     self.query.startThread()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/pyquery.py", line 87, in startThread
#     self.thread.start()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/threading.py", line 892, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
#
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 93, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 227, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 450, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 449, in invoke
#     return f(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 527, in getCentralLayout
#     slice=Slice()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 299, in __init__
#     self.query.startThread()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/pyquery.py", line 87, in startThread
#     self.thread.start()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/threading.py", line 892, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 93, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 227, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 450, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 449, in invoke
#     return f(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 527, in getCentralLayout
#     slice=Slice()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 299, in __init__
#     self.query.startThread()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/pyquery.py", line 87, in startThread
#     self.thread.start()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/threading.py", line 892, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
#
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 93, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 227, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 450, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 449, in invoke
#     return f(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 527, in getCentralLayout
#     slice=Slice()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 299, in __init__
#     self.query.startThread()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/pyquery.py", line 87, in startThread
#     self.thread.start()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/threading.py", line 892, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
#
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 93, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 227, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 450, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 449, in invoke
#     return f(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 527, in getCentralLayout
#     slice=Slice()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 299, in __init__
#     self.query.startThread()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/pyquery.py", line 87, in startThread
#     self.thread.start()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/threading.py", line 892, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
#
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 93, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/server/session.py", line 227, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 450, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 449, in invoke
#     return f(*args, **kwargs)
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 527, in getCentralLayout
#     slice=Slice()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/dashboards.py", line 299, in __init__
#     self.query.startThread()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/site-packages/OpenVisus/pyquery.py", line 87, in startThread
#     self.thread.start()
#   File "/Users/aashishpanta/opt/anaconda3/lib/python3.9/threading.py", line 892, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
