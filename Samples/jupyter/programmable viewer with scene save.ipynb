# %%
import os,sys,pickle,random,threading,time
import platform,subprocess,glob,datetime
import numpy as np
import cv2
from PyQt5 import QtCore
from PyQt5 import QtWidgets

# this is needed to run the Qt5 loop in the background 
# see http://localhost:8888/notebooks/VisibleMale.ipynb#
# %gui qt
# %matplotlib qt
print([it for it in sys.modules.keys() if "pyqt" in it.lower()])

# in case you are in debug mode
sys.path.append(r"C:\projects\OpenVisus\build\RelWithDebInfo")

from OpenVisus                        import *
from OpenVisus.gui                    import *
from OpenVisus.image_utils            import *

# use this function to create a Viewer, solves the problem of window not raising
viewer=None
def CreateViewer():
    global viewer
    viewer=PyViewer()
    viewer_py=sip.wrapinstance(FromCppQtWidget(viewer.c_ptr()), QMainWindow)
    viewer_py.setVisible(True)
    viewer_py.show()
    viewer_py.setFocus()
    viewer_py.showMaximized()
    viewer_py.activateWindow()
    return viewer
# Out:
# ['PyQt5', 'PyQt5.sip', 'PyQt5.QtCore', 'PyQt5.QtGui', 'PyQt5.QtWidgets']
# Starting OpenVisus C:\projects\OpenVisus\build\RelWithDebInfo\OpenVisus\__init__.py 3.8.6 (tags/v3.8.6:db45529, Sep 23 2020, 15:52:53) [MSC v.1927 64 bit (AMD64)] sys.version_info(major=3, minor=8, micro=6, releaselevel='final', serial=0) ...
# QT5_DIR c:\python38\lib\site-packages\PyQt5\Qt

# %%
# do not change this cell for very good reasons (otherwise Qt5 loop won't work)
# this is needed to run the Qt5 loop in the background 
# see http://localhost:8888/notebooks/VisibleMale.ipynb#
import time
time.sleep(2)

# %% [markdown]
# Define some utilities to perform viewer animations

# %%
# //////////////////////////////////////////////////////////////
class RunActions:
    
    def __init__(self):
        self.v=[]
        self.cursor=0
        self.timer=QtCore.QTimer()
        self.timer.timeout.connect(self.onTimer)
        
    def addAction(self, fn,**kwargs):
        self.v.append(lambda : fn(**kwargs))
        
    def addSleep(self,msec):
        self.v.append(msec)
        
    def onTimer(self):
        
        # if the last action was an action and the viewer is still running, I need to wait
        if self.cursor>0 and callable(self.v[self.cursor-1]) and viewer.isRunning():
            return
        
        self.timer.stop()
        
        if self.cursor>= len(self.v):
            return
        
        cur=self.v[self.cursor]
        self.cursor+=1
        
        # is a delay?
        if isinstance(cur,int):
            print("*** Sleep",cur)
            self.timer.start(cur) 
            
        # is a real action, run it and later wait for completition
        elif callable(cur):
            cur()
            self.timer.start(20) 
            
        # there must be a problem
        else:
            raise Exception("internal error")
   
    def start(self): 
        self.timer.start(1) 
        
    def stop(self):
        self.timer.stop()
        
print("Utilities defined")
# Out:
# Utilities defined

# %% [markdown]
# Some predefined actions

# %%
def RotateScene(axis=(0,0,1),angle=10):
    print("*** RotateScene",axis,angle)
    glcamera=viewer.getGLCamera()
    viewer.getGLCamera().setRotation(glcamera.getRotation() * Quaternion(Point3d(axis),math.radians(angle)))
    viewer.refreshAll()
    viewer.postRedisplay()
    
def TakeSnapshot(filename="temp.png",):
    print("*** TakeSnapshotAction",filename)  
    # viewer.takeSnapshot(False,filename) BROKEN
    viewer_py=sip.wrapinstance(FromCppQtWidget(viewer.c_ptr()), QMainWindow)
    screenshot = QtWidgets.QApplication.primaryScreen().grabWindow(viewer_py.winId() )
    screenshot.save(filename)
    
def OpenScene(filename=""):
    print("*** OpenScene",filename)
    viewer.open(filename)
    
def DropSelection():
    print("*** DropSelection")
    viewer.dropSelection()
    
def HideDatasetBounds(uuid="dataset"):
    print("*** HideDatasetBounds",uuid)
    # **** make sure that the dataset node has UUID `dataset` (you can save an xml and inspect it) ***
    dataset_node=DatasetNode.castFrom(viewer.findNodeByUUID(uuid))
    if dataset_node:
        dataset_node.setShowBounds(False)
    else:
        print("Failed to find a node with uuid",uuid)

# %%
# important to create the viewer in a different cell otherwise it won't get the focus
viewer=CreateViewer()

# %%
filename=r"D:\visus_demo\scenes\battery.xml"
actions=RunActions()
actions.addAction(OpenScene,filename=filename)
actions.addAction(DropSelection)
actions.addAction(HideDatasetBounds,uuid="dataset")
for I in range(5):
    actions.addAction(RotateScene,axis=(0,0,1),angle=10)
    actions.addAction(TakeSnapshot,filename=os.path.splitext(filename)[0] + ".{:03d}.png".format(I))
    
    # you can add some sleep between actions but it's not necessary
    # automatically it can wait for the viewer to become idle    
    actions.addSleep(50) 
    
actions.start()
# Out:
# *** OpenScene D:\visus_demo\scenes\battery.xml
# *** DropSelection
# 2021-06-01 16:14:24.271742 PyScriptingNode Got in input (128, 128, 256) uint8 origin Volume
# 2021-06-01 16:14:24.273774 PyScriptingNode Output is  (128, 128, 256) uint8 msec 2
# *** HideDatasetBounds dataset
# *** RotateScene (0, 0, 1) 10
# 2021-06-01 16:14:24.458396 PyScriptingNode Got in input (128, 128, 256) uint8 origin Volume
# 2021-06-01 16:14:24.460421 PyScriptingNode Output is  (128, 128, 256) uint8 msec 1
# *** TakeSnapshotAction D:\visus_demo\scenes\battery.000.png
# *** Sleep 50
# *** RotateScene (0, 0, 1) 10
# *** TakeSnapshotAction D:\visus_demo\scenes\battery.001.png
# 2021-06-01 16:14:24.899151 PyScriptingNode Got in input (128, 128, 256) uint8 origin Volume
# 2021-06-01 16:14:24.901151 PyScriptingNode Output is  (128, 128, 256) uint8 msec 2
# 2021-06-01 16:14:24.960731 PyScriptingNode Got in input (128, 256, 256) uint8 origin Volume
# 2021-06-01 16:14:24.962752 PyScriptingNode Output is  (128, 256, 256) uint8 msec 2
# *** Sleep 50
# *** RotateScene (0, 0, 1) 10
# *** TakeSnapshotAction D:\visus_demo\scenes\battery.002.png
# 2021-06-01 16:14:25.275843 PyScriptingNode Got in input (128, 256, 256) uint8 origin Volume
# 2021-06-01 16:14:25.277848 PyScriptingNode Output is  (128, 256, 256) uint8 msec 2
# *** Sleep 50
# *** RotateScene (0, 0, 1) 10
# *** TakeSnapshotAction D:\visus_demo\scenes\battery.003.png
# 2021-06-01 16:14:25.590975 PyScriptingNode Got in input (128, 128, 256) uint8 origin Volume
# 2021-06-01 16:14:25.592972 PyScriptingNode Output is  (128, 128, 256) uint8 msec 2
# 2021-06-01 16:14:25.654106 PyScriptingNode Got in input (128, 256, 256) uint8 origin Volume
# 2021-06-01 16:14:25.655971 PyScriptingNode Output is  (128, 256, 256) uint8 msec 2
# *** Sleep 50
# *** RotateScene (0, 0, 1) 10
# 2021-06-01 16:14:25.843708 PyScriptingNode Got in input (128, 256, 256) uint8 origin Volume
# 2021-06-01 16:14:25.844707 PyScriptingNode Output is  (128, 256, 256) uint8 msec 2
# *** TakeSnapshotAction D:\visus_demo\scenes\battery.004.png
# *** Sleep 50
# *** RotateScene (0, 0, 1) 10
# *** TakeSnapshotAction D:\visus_demo\scenes\battery.005.png
# 2021-06-01 16:14:26.284999 PyScriptingNode Got in input (128, 256, 256) uint8 origin Volume
# 2021-06-01 16:14:26.287998 PyScriptingNode Output is  (128, 256, 256) uint8 msec 3
# *** Sleep 50
# *** RotateScene (0, 0, 1) 10
# *** TakeSnapshotAction D:\visus_demo\scenes\battery.006.png
# 2021-06-01 16:14:26.598434 PyScriptingNode Got in input (128, 256, 256) uint8 origin Volume
# 2021-06-01 16:14:26.600433 PyScriptingNode Output is  (128, 256, 256) uint8 msec 2
# *** Sleep 50
# *** RotateScene (0, 0, 1) 10
# 2021-06-01 16:14:26.788878 PyScriptingNode Got in input (128, 128, 256) uint8 origin Volume
# 2021-06-01 16:14:26.789878 PyScriptingNode Output is  (128, 128, 256) uint8 msec 2
# *** TakeSnapshotAction D:\visus_demo\scenes\battery.007.png
# *** Sleep 50
# *** RotateScene (0, 0, 1) 10
# 2021-06-01 16:14:27.116743 PyScriptingNode Got in input (128, 128, 256) uint8 origin Volume
# 2021-06-01 16:14:27.118731 PyScriptingNode Output is  (128, 128, 256) uint8 msec 2
# *** TakeSnapshotAction D:\visus_demo\scenes\battery.008.png
# *** Sleep 50
# *** RotateScene (0, 0, 1) 10
# *** TakeSnapshotAction D:\visus_demo\scenes\battery.009.png
# 2021-06-01 16:14:27.559419 PyScriptingNode Got in input (128, 128, 256) uint8 origin Volume
# 2021-06-01 16:14:27.561419 PyScriptingNode Output is  (128, 128, 256) uint8 msec 1
# *** Sleep 50

# %%
# important to create the viewer in a different cell otherwise it won't get the focus
viewer=CreateViewer()

# %%
snapshots=sorted(glob.glob(r"D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot*xml"))

# limit for debugging...
snapshots=snapshots[:2] 

actions=RunActions()
for I,snapshot in enumerate(snapshots):
    print("\t",I,snapshot)
    actions.addAction(OpenScene,filename=snapshot)
    actions.addAction(DropSelection)
    actions.addAction(HideDatasetBounds,uuid="dataset")
    actions.addAction(TakeSnapshot,filename=os.path.splitext(snapshot)[0] + ".png")
    
    # you can add some sleep between actions but it's not necessary
    # automatically it can wait for the viewer to become idle
    actions.addSleep(10) 
    
actions.start()
# Out:
# 	 0 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145607684.xml
# 	 1 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145641394.xml
# 	 2 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145646426.xml
# 	 3 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145715830.xml
# 	 4 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145847913.xml
# 	 5 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145955592.xml
# 	 6 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150116775.xml
# 	 7 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150230900.xml
# 	 8 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150304829.xml
# 	 9 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150311433.xml
# 	 10 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150317444.xml
# 	 11 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150323769.xml
# 	 12 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150331744.xml
# 	 13 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150333018.xml
# 	 14 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150339211.xml
# 	 15 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150347826.xml
# 	 16 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150358139.xml
# 	 17 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150407998.xml
# 	 18 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150413960.xml
# 	 19 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150423331.xml
# 	 20 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150440140.xml
# 	 21 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150445432.xml
# 	 22 D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150451678.xml
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145607684.xml
# *** DropSelection
# 2021-06-01 16:14:43.231058 PyScriptingNode Got in input (347, 98, 704) float32 origin Volume
# 2021-06-01 16:14:43.234076 PyScriptingNode Output is  (347, 98, 704) float32 msec 3
# 2021-06-01 16:14:43.442056 PyScriptingNode Got in input (694, 195, 1407) float32 origin Volume
# 2021-06-01 16:14:43.444070 PyScriptingNode Output is  (694, 195, 1407) float32 msec 1
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145607684.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145641394.xml
# *** DropSelection
# 2021-06-01 16:14:44.644065 PyScriptingNode Got in input (302, 98, 352) float32 origin Volume
# 2021-06-01 16:14:44.646059 PyScriptingNode Output is  (302, 98, 352) float32 msec 2
# 2021-06-01 16:14:44.704056 PyScriptingNode Got in input (604, 195, 704) float32 origin Volume
# 2021-06-01 16:14:44.705069 PyScriptingNode Output is  (604, 195, 704) float32 msec 1
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145641394.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145646426.xml
# *** DropSelection
# 2021-06-01 16:14:45.370145 PyScriptingNode Got in input (302, 98, 176) float32 origin Volume
# 2021-06-01 16:14:45.371146 PyScriptingNode Output is  (302, 98, 176) float32 msec 1
# 2021-06-01 16:14:45.434146 PyScriptingNode Got in input (604, 195, 352) float32 origin Volume
# 2021-06-01 16:14:45.436143 PyScriptingNode Output is  (604, 195, 352) float32 msec 2
# 2021-06-01 16:14:45.821926 PyScriptingNode Got in input (1207, 389, 704) float32 origin Volume
# 2021-06-01 16:14:45.823835 PyScriptingNode Output is  (1207, 389, 704) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145646426.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145715830.xml
# *** DropSelection
# 2021-06-01 16:14:48.652012 PyScriptingNode Got in input (1207, 389, 704) float32 origin Volume
# 2021-06-01 16:14:48.654023 PyScriptingNode Output is  (1207, 389, 704) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145715830.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145847913.xml
# *** DropSelection
# 2021-06-01 16:14:51.403010 PyScriptingNode Got in input (1, 121, 124) float32 origin Slice
# 2021-06-01 16:14:51.405010 PyScriptingNode Output is  (1, 121, 124) float32 msec 2
# 2021-06-01 16:14:51.467021 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice
# 2021-06-01 16:14:51.469021 PyScriptingNode Output is  (1, 242, 248) float32 msec 2
# 2021-06-01 16:14:51.594023 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:14:51.596009 PyScriptingNode Output is  (1, 484, 497) float32 msec 2
# 2021-06-01 16:14:51.597022 PyScriptingNode Got in input (1042, 344, 608) float32 origin Volume
# 2021-06-01 16:14:51.599022 PyScriptingNode Output is  (1042, 344, 608) float32 msec 2
# 2021-06-01 16:14:52.419006 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:14:52.421009 PyScriptingNode Output is  (1, 968, 995) float32 msec 2
# 2021-06-01 16:14:54.172020 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:14:54.174020 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145847913.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145955592.xml
# *** DropSelection
# 2021-06-01 16:14:54.633269 PyScriptingNode Got in input (1, 121, 124) float32 origin Slice
# 2021-06-01 16:14:54.636270 PyScriptingNode Output is  (1, 121, 124) float32 msec 3
# 2021-06-01 16:14:54.695270 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice
# 2021-06-01 16:14:54.697270 PyScriptingNode Output is  (1, 242, 248) float32 msec 2
# 2021-06-01 16:14:54.821268 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:14:54.824270 PyScriptingNode Output is  (1, 484, 497) float32 msec 2
# 2021-06-01 16:14:54.824270 PyScriptingNode Got in input (1031, 344, 602) float32 origin Volume
# 2021-06-01 16:14:54.827270 PyScriptingNode Output is  (1031, 344, 602) float32 msec 2
# 2021-06-01 16:14:55.734270 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:14:55.736269 PyScriptingNode Output is  (1, 968, 995) float32 msec 3
# 2021-06-01 16:14:57.410282 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:14:57.412271 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 1
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531145955592.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150116775.xml
# *** DropSelection
# 2021-06-01 16:14:57.864936 PyScriptingNode Got in input (1, 121, 124) float32 origin Slice
# 2021-06-01 16:14:57.866923 PyScriptingNode Output is  (1, 121, 124) float32 msec 2
# 2021-06-01 16:14:57.867922 PyScriptingNode Got in input (511, 172, 298) float32 origin Volume
# 2021-06-01 16:14:57.869935 PyScriptingNode Output is  (511, 172, 298) float32 msec 2
# 2021-06-01 16:14:57.928013 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice
# 2021-06-01 16:14:57.929935 PyScriptingNode Output is  (1, 242, 248) float32 msec 2
# 2021-06-01 16:14:58.120923 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:14:58.122937 PyScriptingNode Output is  (1, 484, 497) float32 msec 2
# 2021-06-01 16:14:58.123925 PyScriptingNode Got in input (1022, 344, 597) float32 origin Volume
# 2021-06-01 16:14:58.124922 PyScriptingNode Output is  (1022, 344, 597) float32 msec 1
# 2021-06-01 16:14:58.777921 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:14:58.779921 PyScriptingNode Output is  (1, 968, 995) float32 msec 2
# 2021-06-01 16:15:00.500934 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:15:00.502933 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 3
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150116775.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150230900.xml
# *** DropSelection
# 2021-06-01 16:15:00.942710 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice
# 2021-06-01 16:15:00.945709 PyScriptingNode Output is  (1, 242, 248) float32 msec 2
# 2021-06-01 16:15:00.945709 PyScriptingNode Got in input (506, 172, 295) float32 origin Volume
# 2021-06-01 16:15:00.947725 PyScriptingNode Output is  (506, 172, 295) float32 msec 2
# 2021-06-01 16:15:01.116710 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:15:01.118711 PyScriptingNode Output is  (1, 484, 497) float32 msec 2
# 2021-06-01 16:15:01.244708 PyScriptingNode Got in input (1012, 344, 591) float32 origin Volume
# 2021-06-01 16:15:01.245709 PyScriptingNode Output is  (1012, 344, 591) float32 msec 2
# 2021-06-01 16:15:01.998709 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:15:02.000719 PyScriptingNode Output is  (1, 968, 995) float32 msec 2
# 2021-06-01 16:15:03.569709 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:15:03.571709 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 1
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150230900.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150304829.xml
# *** DropSelection
# 2021-06-01 16:15:04.000102 PyScriptingNode Got in input (251, 86, 147) float32 origin Volume
# 2021-06-01 16:15:04.002102 PyScriptingNode Output is  (251, 86, 147) float32 msec 2
# 2021-06-01 16:15:04.003102 PyScriptingNode Got in input (1, 121, 124) float32 origin Slice
# 2021-06-01 16:15:04.005114 PyScriptingNode Output is  (1, 121, 124) float32 msec 2
# 2021-06-01 16:15:04.061101 PyScriptingNode Got in input (501, 172, 293) float32 origin Volume
# 2021-06-01 16:15:04.064104 PyScriptingNode Output is  (501, 172, 293) float32 msec 3
# 2021-06-01 16:15:04.064104 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice
# 2021-06-01 16:15:04.066101 PyScriptingNode Output is  (1, 242, 248) float32 msec 2
# 2021-06-01 16:15:04.319102 PyScriptingNode Got in input (1002, 344, 585) float32 origin Volume
# 2021-06-01 16:15:04.320116 PyScriptingNode Output is  (1002, 344, 585) float32 msec 2
# 2021-06-01 16:15:04.321102 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:15:04.323102 PyScriptingNode Output is  (1, 484, 497) float32 msec 2
# 2021-06-01 16:15:04.972101 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:15:04.974101 PyScriptingNode Output is  (1, 968, 995) float32 msec 2
# 2021-06-01 16:15:06.556114 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:15:06.558100 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 3
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150304829.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150311433.xml
# *** DropSelection
# 2021-06-01 16:15:06.980843 PyScriptingNode Got in input (496, 172, 290) float32 origin Volume
# 2021-06-01 16:15:06.983844 PyScriptingNode Output is  (496, 172, 290) float32 msec 3
# 2021-06-01 16:15:06.984846 PyScriptingNode Got in input (1, 121, 124) float32 origin Slice
# 2021-06-01 16:15:06.986845 PyScriptingNode Output is  (1, 121, 124) float32 msec 3
# 2021-06-01 16:15:07.043855 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice
# 2021-06-01 16:15:07.045843 PyScriptingNode Output is  (1, 242, 248) float32 msec 2
# 2021-06-01 16:15:07.301843 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:15:07.303843 PyScriptingNode Output is  (1, 484, 497) float32 msec 3 2021-06-01 16:15:07.303843 PyScriptingNode Got in input (992, 344, 579) float32 origin Volume
# 2021-06-01 16:15:07.304843 PyScriptingNode Output is  (992, 344, 579) float32 msec 4
#
# 2021-06-01 16:15:08.234841 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:15:08.236843 PyScriptingNode Output is  (1, 968, 995) float32 msec 2
# 2021-06-01 16:15:09.627854 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:15:09.629841 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150311433.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150317444.xml
# *** DropSelection
# 2021-06-01 16:15:10.071313 PyScriptingNode Got in input (1, 121, 124) float32 origin Slice
# 2021-06-01 16:15:10.073317 PyScriptingNode Output is  (1, 121, 124) float32 msec 2
# 2021-06-01 16:15:10.074313 PyScriptingNode Got in input (492, 172, 287) float32 origin Volume
# 2021-06-01 16:15:10.076312 PyScriptingNode Output is  (492, 172, 287) float32 msec 2
# 2021-06-01 16:15:10.260311 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice
# 2021-06-01 16:15:10.262313 PyScriptingNode Output is  (1, 242, 248) float32 msec 2
# 2021-06-01 16:15:10.392314 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:15:10.393313 PyScriptingNode Output is  (1, 484, 497) float32 msec 2
# 2021-06-01 16:15:10.394313 PyScriptingNode Got in input (983, 344, 574) float32 origin Volume
# 2021-06-01 16:15:10.396314 PyScriptingNode Output is  (983, 344, 574) float32 msec 2
# 2021-06-01 16:15:11.310326 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:15:11.312312 PyScriptingNode Output is  (1, 968, 995) float32 msec 1
# 2021-06-01 16:15:12.780324 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:15:12.782313 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150317444.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150323769.xml
# *** DropSelection
# 2021-06-01 16:15:13.226393 PyScriptingNode Got in input (485, 172, 284) float32 origin Volume
# 2021-06-01 16:15:13.228392 PyScriptingNode Output is  (485, 172, 284) float32 msec 2
# 2021-06-01 16:15:13.229392 PyScriptingNode Got in input (1, 121, 124) float32 origin Slice
# 2021-06-01 16:15:13.231393 PyScriptingNode Output is  (1, 121, 124) float32 msec 2
# 2021-06-01 16:15:13.289392 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice
# 2021-06-01 16:15:13.291409 PyScriptingNode Output is  (1, 242, 248) float32 msec 3
# 2021-06-01 16:15:13.485394 PyScriptingNode Got in input (969, 344, 568) float32 origin Volume
# 2021-06-01 16:15:13.486394 PyScriptingNode Output is  (969, 344, 568) float32 msec 2
# 2021-06-01 16:15:13.487393 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:15:13.489394 PyScriptingNode Output is  (1, 484, 497) float32 msec 2
# 2021-06-01 16:15:14.165407 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:15:14.168397 PyScriptingNode Output is  (1, 968, 995) float32 msec 2
# 2021-06-01 16:15:15.859406 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:15:15.861393 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150323769.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150331744.xml
# *** DropSelection
# 2021-06-01 16:15:16.304960 PyScriptingNode Got in input (1, 121, 124) float32 origin Slice 2021-06-01 16:15:16.306959 PyScriptingNode Got in input (464, 172, 273) float32 origin Volume
# 2021-06-01 16:15:16.308973 PyScriptingNode Output is  (464, 172, 273) float32 msec 2
#
# 2021-06-01 16:15:16.309958 PyScriptingNode Output is  (1, 121, 124) float32 msec 5
# 2021-06-01 16:15:16.367973 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice
# 2021-06-01 16:15:16.369973 PyScriptingNode Output is  (1, 242, 248) float32 msec 2
# 2021-06-01 16:15:16.563974 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:15:16.565973 PyScriptingNode Output is  (1, 484, 497) float32 msec 2
# 2021-06-01 16:15:16.566958 PyScriptingNode Got in input (928, 344, 546) float32 origin Volume
# 2021-06-01 16:15:16.568972 PyScriptingNode Output is  (928, 344, 546) float32 msec 2
# 2021-06-01 16:15:17.433971 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:15:17.435958 PyScriptingNode Output is  (1, 968, 995) float32 msec 2
# 2021-06-01 16:15:19.008970 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:15:19.010958 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150331744.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150333018.xml
# *** DropSelection
# 2021-06-01 16:15:19.437174 PyScriptingNode Got in input (464, 172, 273) float32 origin Volume
# 2021-06-01 16:15:19.439181 PyScriptingNode Output is  (464, 172, 273) float32 msec 2
# 2021-06-01 16:15:19.440169 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice
# 2021-06-01 16:15:19.442171 PyScriptingNode Output is  (1, 242, 248) float32 msec 2
# 2021-06-01 16:15:19.691180 PyScriptingNode Got in input (928, 344, 546) float32 origin Volume
# 2021-06-01 16:15:19.693182 PyScriptingNode Output is  (928, 344, 546) float32 msec 2
# 2021-06-01 16:15:19.693182 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:15:19.695181 PyScriptingNode Output is  (1, 484, 497) float32 msec 1
# 2021-06-01 16:15:20.313169 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:15:20.314167 PyScriptingNode Output is  (1, 968, 995) float32 msec 2
# 2021-06-01 16:15:22.028354 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:15:22.030348 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150333018.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150339211.xml
# *** DropSelection
# 2021-06-01 16:15:22.582403 PyScriptingNode Got in input (444, 172, 261) float32 origin Volume
# 2021-06-01 16:15:22.584403 PyScriptingNode Got in input (1, 242, 248) float32 origin Slice 2021-06-01 16:15:22.586402 PyScriptingNode Output is  (444, 172, 261) float32 msec 4
#
# 2021-06-01 16:15:22.586402 PyScriptingNode Output is  (1, 242, 248) float32 msec 1
# 2021-06-01 16:15:22.728402 PyScriptingNode Got in input (888, 344, 523) float32 origin Volume
# 2021-06-01 16:15:22.730402 PyScriptingNode Output is  (888, 344, 523) float32 msec 1
# 2021-06-01 16:15:22.731402 PyScriptingNode Got in input (1, 484, 497) float32 origin Slice
# 2021-06-01 16:15:22.733412 PyScriptingNode Output is  (1, 484, 497) float32 msec 2
# 2021-06-01 16:15:23.354405 PyScriptingNode Got in input (1, 968, 995) float32 origin Slice
# 2021-06-01 16:15:23.356403 PyScriptingNode Output is  (1, 968, 995) float32 msec 2
# 2021-06-01 16:15:24.925414 PyScriptingNode Got in input (1, 1245, 1991) float32 origin Slice
# 2021-06-01 16:15:24.927415 PyScriptingNode Output is  (1, 1245, 1991) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150339211.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150347826.xml
# *** DropSelection
# 2021-06-01 16:15:25.433454 PyScriptingNode Got in input (1, 206, 189) float32 origin Slice
# 2021-06-01 16:15:25.435454 PyScriptingNode Output is  (1, 206, 189) float32 msec 2
# 2021-06-01 16:15:25.435454 PyScriptingNode Got in input (381, 307, 227) float32 origin Volume
# 2021-06-01 16:15:25.437454 PyScriptingNode Output is  (381, 307, 227) float32 msec 2
# 2021-06-01 16:15:25.482456 PyScriptingNode Got in input (1, 413, 379) float32 origin Slice
# 2021-06-01 16:15:25.483454 PyScriptingNode Output is  (1, 413, 379) float32 msec 1
# 2021-06-01 16:15:25.916467 PyScriptingNode Got in input (1, 827, 758) float32 origin Slice
# 2021-06-01 16:15:25.917468 PyScriptingNode Output is  (1, 827, 758) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150347826.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150358139.xml
# *** DropSelection
# 2021-06-01 16:15:26.304857 PyScriptingNode Got in input (1, 227, 229) float32 origin Slice
# 2021-06-01 16:15:26.306856 PyScriptingNode Output is  (1, 227, 229) float32 msec 2
# 2021-06-01 16:15:26.307843 PyScriptingNode Got in input (204, 168, 125) float32 origin Volume
# 2021-06-01 16:15:26.308856 PyScriptingNode Output is  (204, 168, 125) float32 msec 1
# 2021-06-01 16:15:26.431856 PyScriptingNode Got in input (1, 455, 458) float32 origin Slice
# 2021-06-01 16:15:26.433843 PyScriptingNode Output is  (1, 455, 458) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150358139.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150407998.xml
# *** DropSelection
# 2021-06-01 16:15:26.854422 PyScriptingNode Got in input (1, 128, 128) float32 origin Slice
# 2021-06-01 16:15:26.857422 PyScriptingNode Got in input (496, 172, 289) float32 origin Volume
# 2021-06-01 16:15:26.859423 PyScriptingNode Output is  (496, 172, 289) float32 msec 2
# 2021-06-01 16:15:26.859423 PyScriptingNode Output is  (1, 128, 128) float32 msec 5
# 2021-06-01 16:15:26.925435 PyScriptingNode Got in input (1, 256, 256) float32 origin Slice
# 2021-06-01 16:15:26.928423 PyScriptingNode Output is  (1, 256, 256) float32 msec 3
# 2021-06-01 16:15:27.119422 PyScriptingNode Got in input (1, 512, 512) float32 origin Slice
# 2021-06-01 16:15:27.120436 PyScriptingNode Output is  (1, 512, 512) float32 msec 2
# 2021-06-01 16:15:27.121423 PyScriptingNode Got in input (991, 344, 579) float32 origin Volume
# 2021-06-01 16:15:27.123422 PyScriptingNode Output is  (991, 344, 579) float32 msec 1
# 2021-06-01 16:15:27.813435 PyScriptingNode Got in input (1, 1024, 1024) float32 origin Slice
# 2021-06-01 16:15:27.815423 PyScriptingNode Output is  (1, 1024, 1024) float32 msec 1
# 2021-06-01 16:15:29.501434 PyScriptingNode Got in input (1, 1350, 1949) float32 origin Slice
# 2021-06-01 16:15:29.503422 PyScriptingNode Output is  (1, 1350, 1949) float32 msec 1
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150407998.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150413960.xml
# *** DropSelection
# 2021-06-01 16:15:29.948212 PyScriptingNode Got in input (1, 128, 128) float32 origin Slice
# 2021-06-01 16:15:29.951210 PyScriptingNode Output is  (1, 128, 128) float32 msec 3
# 2021-06-01 16:15:29.951210 PyScriptingNode Got in input (491, 172, 287) float32 origin Volume
# 2021-06-01 16:15:29.953210 PyScriptingNode Output is  (491, 172, 287) float32 msec 1
# 2021-06-01 16:15:30.010223 PyScriptingNode Got in input (1, 256, 256) float32 origin Slice
# 2021-06-01 16:15:30.013209 PyScriptingNode Output is  (1, 256, 256) float32 msec 3
# 2021-06-01 16:15:30.207223 PyScriptingNode Got in input (982, 344, 574) float32 origin Volume 2021-06-01 16:15:30.209207 PyScriptingNode Got in input (1, 512, 512) float32 origin Slice
# 2021-06-01 16:15:30.211212 PyScriptingNode Output is  (982, 344, 574) float32 msec 4
#
# 2021-06-01 16:15:30.211212 PyScriptingNode Output is  (1, 512, 512) float32 msec 2
# 2021-06-01 16:15:31.219223 PyScriptingNode Got in input (1, 1024, 1024) float32 origin Slice
# 2021-06-01 16:15:31.221209 PyScriptingNode Output is  (1, 1024, 1024) float32 msec 2
# 2021-06-01 16:15:32.978221 PyScriptingNode Got in input (1, 1350, 1949) float32 origin Slice
# 2021-06-01 16:15:32.980222 PyScriptingNode Output is  (1, 1350, 1949) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150413960.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150423331.xml
# *** DropSelection
# 2021-06-01 16:15:33.427237 PyScriptingNode Got in input (487, 172, 284) float32 origin Volume
# 2021-06-01 16:15:33.429232 PyScriptingNode Output is  (487, 172, 284) float32 msec 2
# 2021-06-01 16:15:33.429232 PyScriptingNode Got in input (1, 128, 128) float32 origin Slice
# 2021-06-01 16:15:33.432245 PyScriptingNode Output is  (1, 128, 128) float32 msec 2
# 2021-06-01 16:15:33.489240 PyScriptingNode Got in input (1, 256, 256) float32 origin Slice
# 2021-06-01 16:15:33.491231 PyScriptingNode Output is  (1, 256, 256) float32 msec 3
# 2021-06-01 16:15:33.733248 PyScriptingNode Got in input (973, 344, 568) float32 origin Volume
# 2021-06-01 16:15:33.735237 PyScriptingNode Output is  (973, 344, 568) float32 msec 1
# 2021-06-01 16:15:33.735237 PyScriptingNode Got in input (1, 512, 512) float32 origin Slice
# 2021-06-01 16:15:33.737241 PyScriptingNode Output is  (1, 512, 512) float32 msec 2
# 2021-06-01 16:15:34.542232 PyScriptingNode Got in input (1, 1024, 1024) float32 origin Slice
# 2021-06-01 16:15:34.544236 PyScriptingNode Output is  (1, 1024, 1024) float32 msec 2
# 2021-06-01 16:15:36.236012 PyScriptingNode Got in input (1, 1350, 1949) float32 origin Slice
# 2021-06-01 16:15:36.238005 PyScriptingNode Output is  (1, 1350, 1949) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150423331.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150440140.xml
# *** DropSelection
# 2021-06-01 16:15:36.666230 PyScriptingNode Got in input (487, 172, 284) float32 origin Volume 2021-06-01 16:15:36.668229 PyScriptingNode Got in input (1, 128, 128) float32 origin Slice
# 2021-06-01 16:15:36.670229 PyScriptingNode Output is  (1, 128, 128) float32 msec 2
#
# 2021-06-01 16:15:36.671228 PyScriptingNode Output is  (487, 172, 284) float32 msec 5
# 2021-06-01 16:15:36.728229 PyScriptingNode Got in input (1, 256, 256) float32 origin Slice
# 2021-06-01 16:15:36.730229 PyScriptingNode Output is  (1, 256, 256) float32 msec 3
# 2021-06-01 16:15:36.985231 PyScriptingNode Got in input (973, 344, 568) float32 origin Volume
# 2021-06-01 16:15:36.987243 PyScriptingNode Output is  (973, 344, 568) float32 msec 1
# 2021-06-01 16:15:36.988244 PyScriptingNode Got in input (1, 512, 512) float32 origin Slice
# 2021-06-01 16:15:36.989231 PyScriptingNode Output is  (1, 512, 512) float32 msec 2
# 2021-06-01 16:15:37.880231 PyScriptingNode Got in input (1, 1024, 1024) float32 origin Slice
# 2021-06-01 16:15:37.881230 PyScriptingNode Output is  (1, 1024, 1024) float32 msec 2
# 2021-06-01 16:15:39.419016 PyScriptingNode Got in input (1, 1350, 1949) float32 origin Slice
# 2021-06-01 16:15:39.422004 PyScriptingNode Output is  (1, 1350, 1949) float32 msec 3
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150440140.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150445432.xml
# *** DropSelection
# 2021-06-01 16:15:39.837053 PyScriptingNode Got in input (475, 172, 279) float32 origin Volume
# 2021-06-01 16:15:39.839056 PyScriptingNode Output is  (475, 172, 279) float32 msec 2
# 2021-06-01 16:15:39.840056 PyScriptingNode Got in input (1, 128, 128) float32 origin Slice
# 2021-06-01 16:15:39.842053 PyScriptingNode Output is  (1, 128, 128) float32 msec 2
# 2021-06-01 16:15:39.898057 PyScriptingNode Got in input (1, 256, 256) float32 origin Slice
# 2021-06-01 16:15:39.900068 PyScriptingNode Output is  (1, 256, 256) float32 msec 2
# 2021-06-01 16:15:40.091055 PyScriptingNode Got in input (949, 344, 558) float32 origin Volume 2021-06-01 16:15:40.092057 PyScriptingNode Got in input (1, 512, 512) float32 origin Slice
# 2021-06-01 16:15:40.094060 PyScriptingNode Output is  (949, 344, 558) float32 msec 3
#
# 2021-06-01 16:15:40.094060 PyScriptingNode Output is  (1, 512, 512) float32 msec 2
# 2021-06-01 16:15:40.940053 PyScriptingNode Got in input (1, 1024, 1024) float32 origin Slice
# 2021-06-01 16:15:40.942054 PyScriptingNode Output is  (1, 1024, 1024) float32 msec 2
# 2021-06-01 16:15:42.592066 PyScriptingNode Got in input (1, 1350, 1949) float32 origin Slice
# 2021-06-01 16:15:42.594057 PyScriptingNode Output is  (1, 1350, 1949) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150445432.png
# *** Sleep 10
# *** OpenScene D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150451678.xml
# *** DropSelection
# 2021-06-01 16:15:43.054058 PyScriptingNode Got in input (457, 172, 269) float32 origin Volume 2021-06-01 16:15:43.057055 PyScriptingNode Got in input (1, 128, 128) float32 origin Slice
# 2021-06-01 16:15:43.059056 PyScriptingNode Output is  (457, 172, 269) float32 msec 5
#
# 2021-06-01 16:15:43.060055 PyScriptingNode Output is  (1, 128, 128) float32 msec 2
# 2021-06-01 16:15:43.116068 PyScriptingNode Got in input (1, 256, 256) float32 origin Slice
# 2021-06-01 16:15:43.119056 PyScriptingNode Output is  (1, 256, 256) float32 msec 3
# 2021-06-01 16:15:43.374056 PyScriptingNode Got in input (1, 512, 512) float32 origin Slice
# 2021-06-01 16:15:43.376053 PyScriptingNode Got in input (914, 344, 538) float32 origin Volume
# 2021-06-01 16:15:43.378057 PyScriptingNode Output is  (914, 344, 538) float32 msec 2
# 2021-06-01 16:15:43.378057 PyScriptingNode Output is  (1, 512, 512) float32 msec 5
# 2021-06-01 16:15:44.117059 PyScriptingNode Got in input (1, 1024, 1024) float32 origin Slice
# 2021-06-01 16:15:44.118059 PyScriptingNode Output is  (1, 1024, 1024) float32 msec 2
# 2021-06-01 16:15:46.139058 PyScriptingNode Got in input (1, 1350, 1949) float32 origin Slice
# 2021-06-01 16:15:46.141057 PyScriptingNode Output is  (1, 1350, 1949) float32 msec 2
# *** HideDatasetBounds dataset
# *** TakeSnapshotAction D:\visus_demo\viewer_control_from_jupyter\honeycomb1\visusviewer.snapshot.20210531150451678.png
# *** Sleep 10

# %%
# Out:
# False
