# %% [markdown]
# # Import OpenVisus

# %%
import os,sys,logging

# import bokeh
os.environ["BOKEH_ALLOW_WS_ORIGIN"]="*" # for debugging 
os.environ["BOKEH_LOG_LEVEL"]="debug"   # for debugging 
import bokeh.io
bokeh.io.output_notebook()

# import OpenVisus
os.environ["VISUS_USE_PUBLIC_IP"]=str(False)
os.environ["VISUS_SSL_TUNNELS"]=""
os.environ["VISUS_CPP_VERBOSE"       ]="0"
os.environ["VISUS_NETSERVICE_VERBOSE"]="0"
os.environ["VISUS_DASHBOARDS_VERBOSE"]="0"
sys.path.append(r"C:\projects\OpenVisus\build\RelWithDebInfo")
import OpenVisus
from OpenVisus.dashboards import ShowApp,TestApp,Slice,Slices
ShowApp(TestApp)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1004">Loading BokehJS ...</span>
#     </div>
# <script id="1005">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:52866/autoload.js?bokeh-autoload-element=1005&bokeh-absolute-url=http://localhost:52866&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %% [markdown]
# # Show viewer

# %%
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
def MyApp(doc):

    # profile=sealstorage
    os.environ["AWS_ACCESS_KEY_ID"]="any"
    os.environ["AWS_SECRET_ACCESS_KEY"]="any"
    os.environ["AWS_ENDPOINT_URL"]="https://maritime.sealstorage.io/api/v0/s3"

    urls=[f"https://maritime.sealstorage.io/api/v0/s3/utah/nasa/dyamond/idx_arco/face{zone}/u_face_{zone}_depth_52_time_0_10269.idx?cached=1" for zone in range(6)]
    palette,palette_range="Turbo256",(-30,60)
    field=None
    logic_to_pixel=[(0.0,1.0), (0.0,1.0), (0.0,10.0)]

    # urls.field=["https://maritime.sealstorage.io/api/v0/s3/utah/nasa/dyamond/mit_output/llc2160_arco/visus.idx?cached=1"],None
    # urls,field=["http://atlantis.sci.utah.edu/mod_visus?dataset=cmip6_cm2&cached=idx"],"ssp585_tasmax"

    viewer=Slices(
        doc=doc,
        show_options=["num_views","palette","dataset","timestep","timestep-delta","field","viewdep","quality","num_refinements","play-button", "play-sec"],
        slice_show_options=["direction","offset","viewdep","status_bar"])

    viewer.setNumberOfViews(3)
    viewer.setDatasets([(url,str(I)) for I,url in enumerate(urls)],"Zone")
    viewer.setDataset(urls[0])
    viewer.setQuality(-3)
    viewer.setNumberOfRefinements(3)
    viewer.setPalette(palette) 
    viewer.setPaletteRange(palette_range)
    viewer.setTimestepDelta(10)
    viewer.setField(field)
    viewer.setLogicToPixel(logic_to_pixel)
    viewer.setDirections([('0','Long'),('1','Lat'),('2','Depth')])

    doc.add_root(viewer.layout)
    
ShowApp(MyApp)
# Out:
# <script id="1385">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:52896/autoload.js?bokeh-autoload-element=1385&bokeh-absolute-url=http://localhost:52896&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
