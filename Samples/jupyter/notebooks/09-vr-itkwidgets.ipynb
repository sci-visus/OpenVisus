# %% [markdown]
# # Import OpenVisus

# %%
# !pip install itkwidgets[all]

# %%
import os,sys
sys.path.append(r"C:\projects\OpenVisus\build\RelWithDebInfo")
import OpenVisus as  ov
from OpenVisus.dashboards import Slice,Slices
from OpenVisus.pyquery import PyQuery
os.environ["VISUS_NETSERVICE_VERBOSE"]="0"
print("OpenVisus imported")
# Out:
# OpenVisus imported

# %% [markdown]
# # Load Dataset

# %%
url=f"http://atlantis.sci.utah.edu/mod_visus?dataset=2kbit1&cached=1"
db=ov.LoadDataset(url)  
print(f"""
Loaded dataset 
   url={db.getUrl()} 
   fields={db.getFields()} 
   logic_box={db.getLogicBox()}
""")
W,H,D=db.getLogicBox()[1]
# Out:
# Loaded dataset
#    url=http://atlantis.sci.utah.edu/mod_visus?dataset=2kbit1
#    fields=['DATA']
#    logic_box=([0, 0, 0], [2048, 2048, 2048])

# %% [markdown]
# # Extract data

# %%
def ReadData(logic_box=None,max_pixels=128*128*128, timestep=None, verbose=True): 
    for it in PyQuery.read(db, logic_box=logic_box, timestep=timestep, max_pixels=max_pixels,num_refinements=1):
        data=it['data']
        msec=it['msec']
        if verbose: print(f"Got data shape={data.shape} dtype={data.dtype} msec={msec}")
        return data
    return None

data=ReadData(logic_box=[[0,0,0],[W,H,D]], timestep=0,max_pixels=128*128*128)
# Out:
# Got data shape=(128, 128, 128) dtype=uint8 msec=380

# %% [markdown]
# # Show volume in itkwidgets

# %%
from itkwidgets import view
view(data)
# Out:
#                 <img id="screenshot_imjoy_window_2ab1bd88-43e6-4e7e-8300-28ddc468035f" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_2ab1bd88-43e6-4e7e-8300-28ddc468035f");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_2ab1bd88-43e6-4e7e-8300-28ddc468035f");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="3d8b3b27-fe4f-4f56-93ca-4ea341b0ac50"></div>
