# %%
import os,sys,logging, urllib,time
import urllib.request
from pprint import pprint
from datetime import datetime

import panel as pn
import numpy as np
import pandas as pd


# this may be dangerous, only for local testing/debugging
os.environ["BOKEH_ALLOW_WS_ORIGIN"]="*"

# if you want more debug info
os.environ["BOKEH_LOG_LEVEL"]="info"   

pn.extension()

import os,sys
sys.path.append(r"C:\projects\OpenVisus\build\RelWithDebInfo")
import OpenVisus as ov
from OpenVisus.dashboards import Slice,Slices
print("OpenVisus imported correctly")

text_input = pn.widgets.TextInput(name='Text Input', placeholder='Enter a string here...')
text_input.value=""   

db=ov.LoadDataset(f"http://atlantis.sci.utah.edu/mod_visus?dataset=david_subsampled&cached=1")    
slice=Slice(doc="panel",sizing_mode='stretch_width') 
slice.show_options=["palette","timestep","field","direction","offset"]
slice.setDataset(db, direction=2)   
slice.setPalette("Greys256", palette_range=(0,255))
slice.setTimestep(db.getTime())
slice.setField(db.getField().name)  

layout=pn.Column(text_input,slice.layout)

timer_count=0
def OnTimer(): 
    global timer_count,slice,text_input
    timer_count+=1
    text_input.value=str(timer_count)   # if I don't do this, all Panel will not work (INCREDIBLE!)
    slice.onTimer()

cb=pn.state.add_periodic_callback(OnTimer, 100) 
layout

# EXECUTE TWICE THIS CELL
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# OpenVisus imported correctly
# Column
#     [0] TextInput(name='Text Input', placeholder='Enter a string here...')
#     [1] Bokeh(Column)
